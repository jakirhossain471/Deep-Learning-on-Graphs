# %%
# Load necessary libraries
import pickle as pkl
import tensorflow as tf
import pandas as pd
import numpy as np
import scipy.sparse as sp
import math
import os
import numpy.linalg as la
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error,mean_absolute_error
import time
from tensorflow.python.framework import ops
ops.reset_default_graph()

# %%
# define necessary functions

def normalized_adj(adj):
    adj = sp.coo_matrix(adj)
    rowsum = np.array(adj.sum(1))
    d_inv_sqrt = np.power(rowsum, -0.5).flatten()
    d_inv_sqrt[np.isinf(d_inv_sqrt)] = 0.
    d_mat_inv_sqrt = sp.diags(d_inv_sqrt)
    normalized_adj = adj.dot(d_mat_inv_sqrt).transpose().dot(d_mat_inv_sqrt).tocoo()
    normalized_adj = normalized_adj.astype(np.float32)
    return normalized_adj

def sparse_to_tuple(mx):
    mx = mx.tocoo()
    coords = np.vstack((mx.row, mx.col)).transpose()
    L = tf.SparseTensor(coords, mx.data, mx.shape)
    return tf.sparse.reorder(L)

def calculate_laplacian(adj, lambda_max=1):
    adj = normalized_adj(adj + sp.eye(adj.shape[0]))
    adj = sp.csr_matrix(adj)
    adj = adj.astype(np.float32)
    return sparse_to_tuple(adj)

def weight_variable_glorot(input_dim, output_dim, name=""):
    init_range = np.sqrt(6.0 / (input_dim + output_dim))
    initial = tf.random.uniform([input_dim, output_dim], minval=-init_range,
                            maxval=init_range, dtype=tf.float32)

    return tf.Variable(initial,name=name)


def preprocess_data(data, time_len, rate, seq_len, pre_len):
    train_size = int(time_len * rate)
    train_data = data[0:train_size]
    test_data = data[train_size:time_len]

    trainX, trainY, testX, testY = [], [], [], []
    for i in range(len(train_data) - seq_len - pre_len):
        a = train_data[i: i + seq_len + pre_len]
        trainX.append(a[0 : seq_len])
        trainY.append(a[seq_len : seq_len + pre_len])
    for i in range(len(test_data) - seq_len -pre_len):
        b = test_data[i: i + seq_len + pre_len]
        testX.append(b[0 : seq_len])
        testY.append(b[seq_len : seq_len + pre_len])

    trainX1 = np.array(trainX)
    trainY1 = np.array(trainY)
    testX1 = np.array(testX)
    testY1 = np.array(testY)
    return trainX1, trainY1, testX1, testY1

# %%
# Create machine learning layers

from tensorflow.compat.v1.nn.rnn_cell import RNNCell
from tensorflow.python.platform import tf_logging as logging


class GRUCell(RNNCell):
    """Gated Recurrent Units. """
    
    def call(self, inputs, **kwargs):
        pass

    def __init__(self, num_units, num_nodes, input_size=None,
                 act=tf.nn.tanh, reuse=None):
        """Gated Recurrent Units."""
        
        super(GRUCell, self).__init__(_reuse=reuse)
        if input_size is not None:
            logging.warn("%s: The input_size parameter is deprecated.", self)
        self._act = act
        self._num_nodes = num_nodes
        self._num_units = num_units



    @property
    def state_size(self):
        return self._num_nodes * self._num_units

    @property
    def output_size(self):
        return self._num_units

    def __call__(self, inputs, state, scope=None):

        with tf.variable_scope(scope or "gru"):
            with tf.variable_scope("gates"): 
                # Reset gate and update gate.
                value = tf.nn.sigmoid(
                    self._linear(inputs, state, 2 * self._num_units, bias=1.0, scope=scope))
                r, u = tf.split(value=value, num_or_size_splits=2, axis=1)
            with tf.variable_scope("candidate"):
                c = self._linear(inputs, r * state, self._num_units, scope=scope)
#                c = self._linear(inputs, r * state, scope=scope)
                if self._act is not None:
                    c = self._act(c)
            new_h = u * state + (1 - u) * c
        return new_h, new_h
        
    
    def _linear(self, inputs, state, output_size, bias=0.0, scope=None):
        ## inputs:(-1,num_nodes)
#        print('1',inputs.get_shape())
        inputs = tf.expand_dims(inputs, 2)
#        print('2',inputs.get_shape())
       
        ## state:(batch,num_node,gru_units)
#        print('2',state.get_shape())
        state = tf.reshape(state, (-1, self._num_nodes, self._num_units))
#        print('2',state.get_shape())
        
        x_h  = tf.concat([inputs, state], axis=2)
        input_size = x_h.get_shape()[2].value
        
        x = tf.reshape(x_h, shape=[-1, input_size])

        scope = tf.get_variable_scope()
        with tf.variable_scope(scope):
            weights = tf.get_variable(
                'weights', [input_size, output_size], initializer=tf.contrib.layers.xavier_initializer())
            biases = tf.get_variable(
                "biases", [output_size], initializer=tf.constant_initializer(bias))

            x = tf.matmul(x, weights)  # (batch_size * self.num_nodes, output_size)          
            x = tf.nn.bias_add(x, biases)

            x = tf.reshape(x, shape=[-1, self._num_nodes ,output_size])
            x = tf.reshape(x, shape=[-1, self._num_nodes * output_size])
        return x

# %%
from tensorflow.compat.v1.nn.rnn_cell import RNNCell

class tgcnCell(RNNCell):
    """Temporal Graph Convolutional Network """

    def call(self, inputs, **kwargs):
        pass

    def __init__(self, num_units, adj, num_nodes, input_size=None,
                 act=tf.nn.tanh, reuse=None):

        super(tgcnCell, self).__init__(_reuse=reuse)
        self._act = act
        self._nodes = num_nodes
        self._units = num_units
        self._adj = []
        self._adj.append(calculate_laplacian(adj))


    @property
    def state_size(self):
        return self._nodes * self._units

    @property
    def output_size(self):
        return self._units

    def __call__(self, inputs, state, scope=None):

        with tf.compat.v1.variable_scope(scope or "tgcn"):
            with tf.compat.v1.variable_scope("gates"):
                value = tf.nn.sigmoid(
                    self._gc(inputs, state, 2 * self._units, bias=1.0, scope=scope))
                r, u = tf.split(value=value, num_or_size_splits=2, axis=1)
            with tf.compat.v1.variable_scope("candidate"):
                r_state = r * state
                c = self._act(self._gc(inputs, r_state, self._units, scope=scope))
            new_h = u * state + (1 - u) * c
        return new_h, new_h


    def _gc(self, inputs, state, output_size, bias=0.0, scope=None):
        ## inputs:(-1,num_nodes)
        inputs = tf.expand_dims(inputs, 2)
        ## state:(batch,num_node,gru_units)
        state = tf.reshape(state, (-1, self._nodes, self._units))
        ## concat
        x_s = tf.concat([inputs, state], axis=2)
        input_size = x_s.get_shape()[2]#.value
        ## (num_node,input_size,-1)
        x0 = tf.transpose(a=x_s, perm=[1, 2, 0])
        x0 = tf.reshape(x0, shape=[self._nodes, -1])

        scope = tf.compat.v1.get_variable_scope()
        with tf.compat.v1.variable_scope(scope):
            for m in self._adj:
                x1 = tf.sparse.sparse_dense_matmul(m, x0)
#                print(x1)
            x = tf.reshape(x1, shape=[self._nodes, input_size,-1])
            x = tf.transpose(a=x,perm=[2,0,1])
            x = tf.reshape(x, shape=[-1, input_size])
            weights = tf.compat.v1.get_variable(
                'weights', [input_size, output_size], initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"))
            x = tf.matmul(x, weights)  # (batch_size * self._nodes, output_size)
            biases = tf.compat.v1.get_variable(
                "biases", [output_size], initializer=tf.compat.v1.constant_initializer(bias, dtype=tf.float32))
            x = tf.nn.bias_add(x, biases)
            x = tf.reshape(x, shape=[-1, self._nodes, output_size])
            x = tf.reshape(x, shape=[-1, self._nodes * output_size])
        return x

# %%
def plot_result(test_result,test_label1,path):
    ##all test result visualization
    fig1 = plt.figure(figsize=(7,1.5))
#    ax1 = fig1.add_subplot(1,1,1)
    a_pred = test_result[:,0]
    a_true = test_label1[:,0]
    plt.plot(a_pred,'r-',label='prediction')
    plt.plot(a_true,'b-',label='true')
    plt.legend(loc='best',fontsize=10)
    plt.savefig(path+'/test_all.jpg')
    plt.show()
    ## oneday test result visualization
    fig1 = plt.figure(figsize=(7,1.5))
#    ax1 = fig1.add_subplot(1,1,1)
    a_pred = test_result[0:96,0]
    a_true = test_label1[0:96,0]
    plt.plot(a_pred,'r-',label="prediction")
    plt.plot(a_true,'b-',label="true")
    plt.legend(loc='best',fontsize=10)
    plt.savefig(path+'/test_oneday.jpg')
    plt.show()

def plot_error(train_rmse,train_loss,test_rmse,test_acc,test_mae,path):
    ###train_rmse & test_rmse
    fig1 = plt.figure(figsize=(5,3))
    plt.plot(train_rmse, 'r-', label="train_rmse")
    plt.plot(test_rmse, 'b-', label="test_rmse")
    plt.legend(loc='best',fontsize=10)
    plt.savefig(path+'/rmse.jpg')
    plt.show()
    #### train_loss & train_rmse
    fig1 = plt.figure(figsize=(5,3))
    plt.plot(train_loss,'b-', label='train_loss')
    plt.legend(loc='best',fontsize=10)
    plt.savefig(path+'/train_loss.jpg')
    plt.show()

    fig1 = plt.figure(figsize=(5,3))
    plt.plot(train_rmse,'b-', label='train_rmse')
    plt.legend(loc='best',fontsize=10)
    plt.savefig(path+'/train_rmse.jpg')
    plt.show()

    ### accuracy
    fig1 = plt.figure(figsize=(5,3))
    plt.plot(test_acc, 'b-', label="test_acc")
    plt.legend(loc='best',fontsize=10)
    plt.savefig(path+'/test_acc.jpg')
    plt.show()
    ### rmse
    fig1 = plt.figure(figsize=(5,3))
    plt.plot(test_rmse, 'b-', label="test_rmse")
    plt.legend(loc='best',fontsize=10)
    plt.savefig(path+'/test_rmse.jpg')
    plt.show()
    ### mae
    fig1 = plt.figure(figsize=(5,3))
    plt.plot(test_mae, 'b-', label="test_mae")
    plt.legend(loc='best',fontsize=10)
    plt.savefig(path+'/test_mae.jpg')
    plt.show()

# %%
def mod_preprocess_data(data,data1, time_len, rate, seq_len, pre_len):
    train_size = int(time_len * rate)
    train_data1 = data[0:train_size]
    train_data2 = data1[0:train_size]
    test_data1 = data[train_size:time_len]
    test_data2 = data1[train_size:time_len]

    trainX, trainY, testX, testY = [], [], [], []
    for i in range(len(train_data1) - seq_len - pre_len):
        a = train_data1[i: i + seq_len + pre_len]
        b = train_data2[i: i + seq_len + pre_len]
        trainX.append(a[0 : seq_len])
        trainY.append(b[seq_len : seq_len + pre_len])
    for i in range(len(test_data1) - seq_len -pre_len):
        c = test_data1[i: i + seq_len + pre_len]
        d = test_data2[i: i + seq_len + pre_len]
        testX.append(c[0 : seq_len])
        testY.append(d[seq_len : seq_len + pre_len])

    trainX1 = np.array(trainX)
    trainY1 = np.array(trainY)
    testX1 = np.array(testX)
    testY1 = np.array(testY)
    return trainX1, trainY1, testX1, testY1

# %%
###### Settings ######
time_start = time.time()

data = pd.read_csv('voltage_angle.csv',header=None)    #load data
adj = np.mat(pd.read_csv('AdjMatrix.csv',header=None)) #load adjacency matrix

theta_df = data
#theta_df = pd.read_csv('voltage_magnitude.csv',header=None) # clean data
#theta_df = pd.read_csv('Noise100.csv',header=None).T # noisey data
theta_df.columns = np.linspace(1,118,118) #setting BUS indexes

#print(theta_df.shape)
Opt_PMU1 = [2,5,10,11,12,17,20,23,25,29,34,37,40,45,49,50,51,52,59,65,66,71,75,77,80,85,87,91,94,101,105,110,114,116]
Opt_PMU2 = [1,5,10,12,13,17,21,25,28,34,37,40,45,49,52,56,62,63,68,70,71,75,77,80,85,87,90,94,102,105,110,114]
Opt_PMU3 = [1,4,5,6,8,9,10,11,12,17,18,19,20,21,22,24,25,26,27,28,30,32,34,37,40,43,45,49,50,56,59,61,62,63,64,65,67,68,69,70,71,72,73,75,77,79,80,83,85,87,89,90,92,94,96,100,101,105,106,108,110,111,112,114,116,117,118]
M, N = theta_df.shape
Noise = pd.DataFrame(np.random.normal(0,1,[M,N]),columns = np.linspace(1,118,118))
Opti_theta = Noise
Opti_theta[Opt_PMU2] = theta_df[Opt_PMU2] # data with measurements from only selected PMUS 



Data = np.mat(data) # subset of PMU data
Data1 = np.mat(Opti_theta)  # fullset of PMU data

#### normalization
max_value = np.max(Data)
Data  = Data/max_value
Data1 = Data1/max_value

time_len = data.shape[0]
num_nodes = data.shape[1]

## Initialization parameters
seq_len = 7
pre_len = 1
learning_rate =  0.001
training_epoch = 250
gru_units =  64
train_rate = 0.8
batch_size = 32
model_name = 'tgcn'
data_name = 'theta'



#trainX, trainY, testX, testY = preprocess_data(data1, time_len, train_rate, seq_len, pre_len)

trainX, trainY, testX, testY = mod_preprocess_data(Data1,Data, time_len, train_rate, seq_len, pre_len)

totalbatch = int(trainX.shape[0]/batch_size)
training_data_count = len(trainX)

# %%
data.shape, Opti_theta.shape, trainX.shape, trainY.shape,testX.shape,testY.shape, max_value
# Out:
# ((2880, 118),
#  (2880, 118),
#  (2296, 7, 118),
#  (2296, 1, 118),
#  (568, 7, 118),
#  (568, 1, 118),
#  41.098691675805)

# %%
##### Model definition #####
def TGCN(_X, _weights, _biases):
    ###
    cell_1 = tgcnCell(gru_units, adj, num_nodes=num_nodes)
    cell = tf.compat.v1.nn.rnn_cell.MultiRNNCell([cell_1], state_is_tuple=True)
    _X = tf.unstack(_X, axis=1)
    outputs, states = tf.compat.v1.nn.static_rnn(cell, _X, dtype=tf.float32)
    m = []
    for i in outputs:
        o = tf.reshape(i,shape=[-1,num_nodes,gru_units])
        o = tf.reshape(o,shape=[-1,gru_units])
        m.append(o)
    last_output = m[-1]
    output = tf.matmul(last_output, _weights['out']) + _biases['out']
    output = tf.reshape(output,shape=[-1,num_nodes,pre_len])
    output = tf.transpose(a=output, perm=[0,2,1])
    output = tf.reshape(output, shape=[-1,num_nodes])
    return output, m, states
        
def GRU(_X, _weights, _biases):
    ###
    cell_1 = GRUCell(gru_units, num_nodes=num_nodes)
    cell = tf.compat.v1.nn.rnn_cell.MultiRNNCell([cell_1], state_is_tuple=True)
    _X = tf.unstack(_X, axis=1)
    outputs, states = tf.compat.v1.nn.static_rnn(cell, _X, dtype=tf.float32)
    m = []
    for i in outputs:
        o = tf.reshape(i,shape=[-1,num_nodes,gru_units])
        o = tf.reshape(o,shape=[-1,gru_units])
        m.append(o)
    last_output = m[-1]
    output = tf.matmul(last_output, _weights['out']) + _biases['out']
    output = tf.reshape(output,shape=[-1,num_nodes,pre_len])
    output = tf.transpose(a=output, perm=[0,2,1])
    output = tf.reshape(output, shape=[-1,num_nodes])
    return output, m, states

# %%
###### placeholders ######
tf.compat.v1.disable_eager_execution()
inputs = tf.compat.v1.placeholder(tf.float32, shape=[None, seq_len, num_nodes])
labels = tf.compat.v1.placeholder(tf.float32, shape=[None, pre_len, num_nodes])

# Graph weights
weights = {
    'out': tf.Variable(tf.random.normal([gru_units, pre_len], mean=1.0), name='weight_o')}
biases = {
    'out': tf.Variable(tf.random.normal([pre_len]),name='bias_o')}

pred,ttts,ttto = TGCN(inputs, weights, biases) # build the model

y_pred = pred

# %%
###### optimizer ######
lambda_loss = 0.0015
Lreg = lambda_loss * sum(tf.nn.l2_loss(tf_var) for tf_var in tf.compat.v1.trainable_variables())
label = tf.reshape(labels, [-1,num_nodes])
##loss
loss = tf.reduce_mean(input_tensor=tf.nn.l2_loss(y_pred-label) + Lreg)
##rmse
error = tf.sqrt(tf.reduce_mean(input_tensor=tf.square(y_pred-label)))
optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate).minimize(loss)

# %%
###### Initialize session ######
variables = tf.compat.v1.global_variables()
saver = tf.compat.v1.train.Saver(tf.compat.v1.global_variables())
#sess = tf.Session()
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))
sess.run(tf.compat.v1.global_variables_initializer())

out = 'out/%s'%(model_name)
#out = 'out/%s_%s'%(model_name,'perturbation')
path1 = '%s_%s_lr%r_batch%r_unit%r_seq%r_pre%r_epoch%r'%(model_name,data_name,learning_rate,batch_size,gru_units,seq_len,pre_len,training_epoch)
path = os.path.join(out,path1)
if not os.path.exists(path):
    os.makedirs(path)

# %%
###### evaluation ######
def evaluation(a,b):
    rmse = math.sqrt(mean_squared_error(a,b))
    mae = mean_absolute_error(a, b)
    F_norm = la.norm(a-b,'fro')/la.norm(a,'fro')
    r2 = 1-((a-b)**2).sum()/((a-a.mean())**2).sum()
    var = 1-(np.var(a-b))/np.var(a)
    return rmse, mae, 1-F_norm, r2, var


x_axe,batch_loss,batch_rmse,batch_pred = [], [], [], []
test_loss,test_rmse,test_mae,test_acc,test_r2,test_var,test_pred = [],[],[],[],[],[],[]

# %%
##### Trainning Loop #####

for epoch in range(training_epoch):
    for m in range(totalbatch):
        mini_batch = trainX[m * batch_size : (m+1) * batch_size]
        mini_label = trainY[m * batch_size : (m+1) * batch_size]
        _, loss1, rmse1, train_output = sess.run([optimizer, loss, error, y_pred],
                                                 feed_dict = {inputs:mini_batch, labels:mini_label})
        batch_loss.append(loss1)
        batch_rmse.append(rmse1 * max_value)

     # Test completely at every epoch
    loss2, rmse2, test_output = sess.run([loss, error, y_pred],
                                         feed_dict = {inputs:testX, labels:testY})
    test_label = np.reshape(testY,[-1,num_nodes])
    rmse, mae, acc, r2_score, var_score = evaluation(test_label, test_output)
    test_label1 = test_label * max_value
    test_output1 = test_output * max_value
    test_loss.append(loss2)
    test_rmse.append(rmse * max_value)
    test_mae.append(mae * max_value)
    test_acc.append(acc)
    test_r2.append(r2_score)
    test_var.append(var_score)
    test_pred.append(test_output1)

    print('Iter:{}'.format(epoch),
          'train_rmse:{:.4}'.format(batch_rmse[-1]),
          'test_loss:{:.4}'.format(loss2),
          'test_rmse:{:.4}'.format(rmse),
          'test_acc:{:.4}'.format(acc))

    if (epoch % 500 == 0):
        saver.save(sess, path+'/model_100/TGCN_pre_%r'%epoch, global_step = epoch)

time_end = time.time()
print(time_end-time_start,'s')
# Out:
# Iter:0 train_rmse:4.506 test_loss:410.4 test_rmse:0.1106 test_acc:0.7913
# Iter:1 train_rmse:4.179 test_loss:356.6 test_rmse:0.1031 test_acc:0.8054
# Iter:2 train_rmse:4.007 test_loss:327.5 test_rmse:0.09881 test_acc:0.8135
# Iter:3 train_rmse:3.887 test_loss:308.7 test_rmse:0.09592 test_acc:0.819
# Iter:4 train_rmse:3.78 test_loss:287.6 test_rmse:0.09258 test_acc:0.8253
# Iter:5 train_rmse:3.597 test_loss:263.9 test_rmse:0.08867 test_acc:0.8327
# Iter:6 train_rmse:3.529 test_loss:246.8 test_rmse:0.08574 test_acc:0.8382
# Iter:7 train_rmse:3.507 test_loss:231.4 test_rmse:0.08302 test_acc:0.8433
# Iter:8 train_rmse:3.265 test_loss:218.0 test_rmse:0.08058 test_acc:0.8479
# Iter:9 train_rmse:3.37 test_loss:210.3 test_rmse:0.07914 test_acc:0.8507
# Iter:10 train_rmse:3.163 test_loss:194.9 test_rmse:0.07617 test_acc:0.8563
# Iter:11 train_rmse:3.152 test_loss:188.6 test_rmse:0.07492 test_acc:0.8586
# Iter:12 train_rmse:3.255 test_loss:194.6 test_rmse:0.07611 test_acc:0.8564
# Iter:13 train_rmse:3.097 test_loss:175.9 test_rmse:0.07234 test_acc:0.8635
# Iter:14 train_rmse:3.026 test_loss:167.2 test_rmse:0.07054 test_acc:0.8669
# Iter:15 train_rmse:2.954 test_loss:159.0 test_rmse:0.06877 test_acc:0.8702
# Iter:16 train_rmse:2.889 test_loss:151.8 test_rmse:0.06718 test_acc:0.8732
# Iter:17 train_rmse:2.834 test_loss:145.6 test_rmse:0.06578 test_acc:0.8759
# Iter:18 train_rmse:2.788 test_loss:140.0 test_rmse:0.06451 test_acc:0.8783
# Iter:19 train_rmse:2.746 test_loss:134.7 test_rmse:0.06327 test_acc:0.8806
# Iter:20 train_rmse:2.703 test_loss:129.5 test_rmse:0.06203 test_acc:0.8829
# Iter:21 train_rmse:2.657 test_loss:124.3 test_rmse:0.06076 test_acc:0.8853
# Iter:22 train_rmse:2.608 test_loss:118.9 test_rmse:0.05943 test_acc:0.8879
# Iter:23 train_rmse:2.553 test_loss:113.4 test_rmse:0.05803 test_acc:0.8905
# Iter:24 train_rmse:2.494 test_loss:107.8 test_rmse:0.05656 test_acc:0.8933
# Iter:25 train_rmse:2.428 test_loss:102.2 test_rmse:0.05506 test_acc:0.8961
# Iter:26 train_rmse:2.361 test_loss:96.95 test_rmse:0.05362 test_acc:0.8988
# Iter:27 train_rmse:2.296 test_loss:92.2 test_rmse:0.05228 test_acc:0.9013
# Iter:28 train_rmse:2.235 test_loss:87.93 test_rmse:0.05104 test_acc:0.9037
# Iter:29 train_rmse:2.179 test_loss:84.08 test_rmse:0.0499 test_acc:0.9058
# Iter:30 train_rmse:2.126 test_loss:80.6 test_rmse:0.04885 test_acc:0.9078
# Iter:31 train_rmse:2.078 test_loss:77.46 test_rmse:0.04788 test_acc:0.9096
# Iter:32 train_rmse:2.034 test_loss:74.61 test_rmse:0.04698 test_acc:0.9113
# Iter:33 train_rmse:1.994 test_loss:72.01 test_rmse:0.04615 test_acc:0.9129
# Iter:34 train_rmse:1.956 test_loss:69.63 test_rmse:0.04537 test_acc:0.9144
# Iter:35 train_rmse:1.922 test_loss:67.44 test_rmse:0.04464 test_acc:0.9158
# Iter:36 train_rmse:1.891 test_loss:65.42 test_rmse:0.04396 test_acc:0.917
# Iter:37 train_rmse:1.863 test_loss:63.56 test_rmse:0.04332 test_acc:0.9182
# Iter:38 train_rmse:1.836 test_loss:61.82 test_rmse:0.04272 test_acc:0.9194
# Iter:39 train_rmse:1.812 test_loss:60.2 test_rmse:0.04215 test_acc:0.9205
# Iter:40 train_rmse:1.789 test_loss:58.67 test_rmse:0.04161 test_acc:0.9215
# Iter:41 train_rmse:1.767 test_loss:57.24 test_rmse:0.04109 test_acc:0.9225
# Iter:42 train_rmse:1.747 test_loss:55.88 test_rmse:0.04059 test_acc:0.9234
# Iter:43 train_rmse:1.727 test_loss:54.61 test_rmse:0.04012 test_acc:0.9243
# Iter:44 train_rmse:1.707 test_loss:53.41 test_rmse:0.03967 test_acc:0.9251
# Iter:45 train_rmse:1.688 test_loss:52.27 test_rmse:0.03924 test_acc:0.9259
# Iter:46 train_rmse:1.67 test_loss:51.21 test_rmse:0.03883 test_acc:0.9267
# Iter:47 train_rmse:1.653 test_loss:50.2 test_rmse:0.03844 test_acc:0.9275
# Iter:48 train_rmse:1.637 test_loss:49.24 test_rmse:0.03807 test_acc:0.9282
# Iter:49 train_rmse:1.622 test_loss:48.34 test_rmse:0.03771 test_acc:0.9288
# Iter:50 train_rmse:1.607 test_loss:47.47 test_rmse:0.03737 test_acc:0.9295
# Iter:51 train_rmse:1.594 test_loss:46.64 test_rmse:0.03703 test_acc:0.9301
# Iter:52 train_rmse:1.581 test_loss:45.84 test_rmse:0.03671 test_acc:0.9307
# Iter:53 train_rmse:1.569 test_loss:45.08 test_rmse:0.0364 test_acc:0.9313
# Iter:54 train_rmse:1.558 test_loss:44.36 test_rmse:0.0361 test_acc:0.9319
# Iter:55 train_rmse:1.548 test_loss:43.67 test_rmse:0.03582 test_acc:0.9324
# Iter:56 train_rmse:1.538 test_loss:43.02 test_rmse:0.03554 test_acc:0.9329
# Iter:57 train_rmse:1.528 test_loss:42.41 test_rmse:0.03529 test_acc:0.9334
# Iter:58 train_rmse:1.519 test_loss:41.84 test_rmse:0.03505 test_acc:0.9339
# Iter:59 train_rmse:1.51 test_loss:41.31 test_rmse:0.03482 test_acc:0.9343
# Iter:60 train_rmse:1.501 test_loss:40.83 test_rmse:0.03461 test_acc:0.9347
# Iter:61 train_rmse:1.492 test_loss:40.39 test_rmse:0.03442 test_acc:0.935
# Iter:62 train_rmse:1.483 test_loss:39.99 test_rmse:0.03425 test_acc:0.9354
# Iter:63 train_rmse:1.474 test_loss:39.62 test_rmse:0.03409 test_acc:0.9357
# Iter:64 train_rmse:1.466 test_loss:39.29 test_rmse:0.03394 test_acc:0.936
# Iter:65 train_rmse:1.458 test_loss:38.98 test_rmse:0.0338 test_acc:0.9362
# Iter:66 train_rmse:1.453 test_loss:38.69 test_rmse:0.03368 test_acc:0.9365
# Iter:67 train_rmse:1.45 test_loss:38.46 test_rmse:0.03357 test_acc:0.9366
# Iter:68 train_rmse:1.45 test_loss:38.3 test_rmse:0.0335 test_acc:0.9368
# Iter:69 train_rmse:1.452 test_loss:38.21 test_rmse:0.03346 test_acc:0.9369
# Iter:70 train_rmse:1.455 test_loss:38.2 test_rmse:0.03346 test_acc:0.9369
# Iter:71 train_rmse:1.458 test_loss:38.27 test_rmse:0.03349 test_acc:0.9368
# Iter:72 train_rmse:1.461 test_loss:38.43 test_rmse:0.03356 test_acc:0.9367
# Iter:73 train_rmse:1.465 test_loss:38.69 test_rmse:0.03367 test_acc:0.9365
# Iter:74 train_rmse:1.468 test_loss:39.05 test_rmse:0.03383 test_acc:0.9362
# Iter:75 train_rmse:1.47 test_loss:39.54 test_rmse:0.03405 test_acc:0.9358
# Iter:76 train_rmse:1.471 test_loss:40.14 test_rmse:0.03431 test_acc:0.9353
# Iter:77 train_rmse:1.47 test_loss:40.87 test_rmse:0.03463 test_acc:0.9347
# Iter:78 train_rmse:1.464 test_loss:41.67 test_rmse:0.03497 test_acc:0.934
# Iter:79 train_rmse:1.451 test_loss:42.44 test_rmse:0.0353 test_acc:0.9334
# Iter:80 train_rmse:1.43 test_loss:42.96 test_rmse:0.03552 test_acc:0.933
# Iter:81 train_rmse:1.406 test_loss:43.02 test_rmse:0.03554 test_acc:0.9329
# Iter:82 train_rmse:1.401 test_loss:43.18 test_rmse:0.03561 test_acc:0.9328
# Iter:83 train_rmse:1.429 test_loss:44.74 test_rmse:0.03626 test_acc:0.9316
# Iter:84 train_rmse:1.46 test_loss:47.05 test_rmse:0.03719 test_acc:0.9298
# Iter:85 train_rmse:1.472 test_loss:48.73 test_rmse:0.03786 test_acc:0.9286
# Iter:86 train_rmse:1.472 test_loss:49.76 test_rmse:0.03826 test_acc:0.9278
# Iter:87 train_rmse:1.468 test_loss:50.44 test_rmse:0.03853 test_acc:0.9273
# Iter:88 train_rmse:1.461 test_loss:50.91 test_rmse:0.03871 test_acc:0.927
# Iter:89 train_rmse:1.452 test_loss:51.23 test_rmse:0.03884 test_acc:0.9267
# Iter:90 train_rmse:1.443 test_loss:51.43 test_rmse:0.03891 test_acc:0.9266
# Iter:91 train_rmse:1.432 test_loss:51.53 test_rmse:0.03895 test_acc:0.9265
# Iter:92 train_rmse:1.422 test_loss:51.55 test_rmse:0.03896 test_acc:0.9265
# Iter:93 train_rmse:1.411 test_loss:51.51 test_rmse:0.03894 test_acc:0.9265
# Iter:94 train_rmse:1.4 test_loss:51.41 test_rmse:0.0389 test_acc:0.9266
# Iter:95 train_rmse:1.389 test_loss:51.27 test_rmse:0.03885 test_acc:0.9267
# Iter:96 train_rmse:1.379 test_loss:51.1 test_rmse:0.03879 test_acc:0.9268
# Iter:97 train_rmse:1.368 test_loss:50.91 test_rmse:0.03871 test_acc:0.927
# Iter:98 train_rmse:1.358 test_loss:50.69 test_rmse:0.03863 test_acc:0.9271
# Iter:99 train_rmse:1.348 test_loss:50.47 test_rmse:0.03854 test_acc:0.9273
# Iter:100 train_rmse:1.338 test_loss:50.23 test_rmse:0.03845 test_acc:0.9274
# Iter:101 train_rmse:1.328 test_loss:49.99 test_rmse:0.03836 test_acc:0.9276
# Iter:102 train_rmse:1.318 test_loss:49.74 test_rmse:0.03826 test_acc:0.9278
# Iter:103 train_rmse:1.309 test_loss:49.48 test_rmse:0.03816 test_acc:0.928
# Iter:104 train_rmse:1.299 test_loss:49.22 test_rmse:0.03806 test_acc:0.9282
# Iter:105 train_rmse:1.29 test_loss:48.96 test_rmse:0.03795 test_acc:0.9284
# Iter:106 train_rmse:1.281 test_loss:48.7 test_rmse:0.03785 test_acc:0.9286
# Iter:107 train_rmse:1.272 test_loss:48.43 test_rmse:0.03775 test_acc:0.9288
# Iter:108 train_rmse:1.263 test_loss:48.16 test_rmse:0.03764 test_acc:0.929
# Iter:109 train_rmse:1.255 test_loss:47.89 test_rmse:0.03753 test_acc:0.9292
# Iter:110 train_rmse:1.246 test_loss:47.62 test_rmse:0.03742 test_acc:0.9294
# Iter:111 train_rmse:1.238 test_loss:47.35 test_rmse:0.03732 test_acc:0.9296
# Iter:112 train_rmse:1.229 test_loss:47.08 test_rmse:0.03721 test_acc:0.9298
# Iter:113 train_rmse:1.221 test_loss:46.81 test_rmse:0.0371 test_acc:0.93
# Iter:114 train_rmse:1.213 test_loss:46.54 test_rmse:0.03699 test_acc:0.9302
# Iter:115 train_rmse:1.205 test_loss:46.27 test_rmse:0.03689 test_acc:0.9304
# Iter:116 train_rmse:1.197 test_loss:46.01 test_rmse:0.03678 test_acc:0.9306
# Iter:117 train_rmse:1.19 test_loss:45.74 test_rmse:0.03667 test_acc:0.9308
# Iter:118 train_rmse:1.182 test_loss:45.48 test_rmse:0.03656 test_acc:0.931
# Iter:119 train_rmse:1.175 test_loss:45.22 test_rmse:0.03646 test_acc:0.9312
# Iter:120 train_rmse:1.168 test_loss:44.97 test_rmse:0.03636 test_acc:0.9314
# Iter:121 train_rmse:1.161 test_loss:44.72 test_rmse:0.03625 test_acc:0.9316
# Iter:122 train_rmse:1.154 test_loss:44.47 test_rmse:0.03615 test_acc:0.9318
# Iter:123 train_rmse:1.147 test_loss:44.23 test_rmse:0.03605 test_acc:0.932
# Iter:124 train_rmse:1.141 test_loss:43.99 test_rmse:0.03595 test_acc:0.9322
# Iter:125 train_rmse:1.134 test_loss:43.76 test_rmse:0.03585 test_acc:0.9323
# Iter:126 train_rmse:1.128 test_loss:43.53 test_rmse:0.03576 test_acc:0.9325
# Iter:127 train_rmse:1.122 test_loss:43.31 test_rmse:0.03567 test_acc:0.9327
# Iter:128 train_rmse:1.117 test_loss:43.1 test_rmse:0.03558 test_acc:0.9329
# Iter:129 train_rmse:1.111 test_loss:42.9 test_rmse:0.0355 test_acc:0.933
# Iter:130 train_rmse:1.106 test_loss:42.7 test_rmse:0.03541 test_acc:0.9332
# Iter:131 train_rmse:1.101 test_loss:42.51 test_rmse:0.03533 test_acc:0.9333
# Iter:132 train_rmse:1.097 test_loss:42.33 test_rmse:0.03526 test_acc:0.9335
# Iter:133 train_rmse:1.092 test_loss:42.15 test_rmse:0.03518 test_acc:0.9336
# Iter:134 train_rmse:1.088 test_loss:41.99 test_rmse:0.03511 test_acc:0.9337
# Iter:135 train_rmse:1.085 test_loss:41.82 test_rmse:0.03504 test_acc:0.9339
# Iter:136 train_rmse:1.081 test_loss:41.67 test_rmse:0.03498 test_acc:0.934
# Iter:137 train_rmse:1.078 test_loss:41.51 test_rmse:0.03491 test_acc:0.9341
# Iter:138 train_rmse:1.075 test_loss:41.36 test_rmse:0.03485 test_acc:0.9342
# Iter:139 train_rmse:1.072 test_loss:41.21 test_rmse:0.03478 test_acc:0.9344
# Iter:140 train_rmse:1.07 test_loss:41.06 test_rmse:0.03472 test_acc:0.9345
# Iter:141 train_rmse:1.067 test_loss:40.91 test_rmse:0.03465 test_acc:0.9346
# Iter:142 train_rmse:1.065 test_loss:40.76 test_rmse:0.03459 test_acc:0.9347
# Iter:143 train_rmse:1.062 test_loss:40.6 test_rmse:0.03452 test_acc:0.9349
# Iter:144 train_rmse:1.06 test_loss:40.44 test_rmse:0.03445 test_acc:0.935
# Iter:145 train_rmse:1.058 test_loss:40.28 test_rmse:0.03438 test_acc:0.9351
# Iter:146 train_rmse:1.055 test_loss:40.11 test_rmse:0.03431 test_acc:0.9353
# Iter:147 train_rmse:1.053 test_loss:39.95 test_rmse:0.03424 test_acc:0.9354
# Iter:148 train_rmse:1.051 test_loss:39.78 test_rmse:0.03416 test_acc:0.9355
# Iter:149 train_rmse:1.048 test_loss:39.61 test_rmse:0.03409 test_acc:0.9357
# Iter:150 train_rmse:1.046 test_loss:39.43 test_rmse:0.03401 test_acc:0.9358
# Iter:151 train_rmse:1.043 test_loss:39.26 test_rmse:0.03394 test_acc:0.936
# Iter:152 train_rmse:1.041 test_loss:39.09 test_rmse:0.03386 test_acc:0.9361
# Iter:153 train_rmse:1.038 test_loss:38.91 test_rmse:0.03379 test_acc:0.9362
# Iter:154 train_rmse:1.036 test_loss:38.74 test_rmse:0.03371 test_acc:0.9364
# Iter:155 train_rmse:1.033 test_loss:38.56 test_rmse:0.03363 test_acc:0.9365
# Iter:156 train_rmse:1.03 test_loss:38.39 test_rmse:0.03355 test_acc:0.9367
# Iter:157 train_rmse:1.028 test_loss:38.21 test_rmse:0.03348 test_acc:0.9368
# Iter:158 train_rmse:1.025 test_loss:38.04 test_rmse:0.0334 test_acc:0.937
# Iter:159 train_rmse:1.023 test_loss:37.86 test_rmse:0.03332 test_acc:0.9371
# Iter:160 train_rmse:1.02 test_loss:37.69 test_rmse:0.03324 test_acc:0.9373
# Iter:161 train_rmse:1.017 test_loss:37.52 test_rmse:0.03317 test_acc:0.9374
# Iter:162 train_rmse:1.015 test_loss:37.35 test_rmse:0.03309 test_acc:0.9376
# Iter:163 train_rmse:1.012 test_loss:37.17 test_rmse:0.03301 test_acc:0.9377
# Iter:164 train_rmse:1.009 test_loss:37.0 test_rmse:0.03293 test_acc:0.9379
# Iter:165 train_rmse:1.007 test_loss:36.83 test_rmse:0.03286 test_acc:0.938
# Iter:166 train_rmse:1.004 test_loss:36.66 test_rmse:0.03278 test_acc:0.9381
# Iter:167 train_rmse:1.001 test_loss:36.49 test_rmse:0.0327 test_acc:0.9383
# Iter:168 train_rmse:0.9986 test_loss:36.32 test_rmse:0.03263 test_acc:0.9384
# Iter:169 train_rmse:0.9959 test_loss:36.16 test_rmse:0.03255 test_acc:0.9386
# Iter:170 train_rmse:0.9932 test_loss:35.99 test_rmse:0.03247 test_acc:0.9387
# Iter:171 train_rmse:0.9906 test_loss:35.82 test_rmse:0.0324 test_acc:0.9389
# Iter:172 train_rmse:0.9879 test_loss:35.66 test_rmse:0.03232 test_acc:0.939
# Iter:173 train_rmse:0.9852 test_loss:35.49 test_rmse:0.03224 test_acc:0.9392
# Iter:174 train_rmse:0.9825 test_loss:35.33 test_rmse:0.03217 test_acc:0.9393
# Iter:175 train_rmse:0.9797 test_loss:35.16 test_rmse:0.03209 test_acc:0.9394
# Iter:176 train_rmse:0.9771 test_loss:35.0 test_rmse:0.03202 test_acc:0.9396
# Iter:177 train_rmse:0.9744 test_loss:34.84 test_rmse:0.03194 test_acc:0.9397
# Iter:178 train_rmse:0.9717 test_loss:34.68 test_rmse:0.03187 test_acc:0.9399
# Iter:179 train_rmse:0.969 test_loss:34.52 test_rmse:0.03179 test_acc:0.94
# Iter:180 train_rmse:0.9663 test_loss:34.36 test_rmse:0.03172 test_acc:0.9401
# Iter:181 train_rmse:0.9637 test_loss:34.21 test_rmse:0.03164 test_acc:0.9403
# Iter:182 train_rmse:0.961 test_loss:34.05 test_rmse:0.03157 test_acc:0.9404
# Iter:183 train_rmse:0.9583 test_loss:33.9 test_rmse:0.0315 test_acc:0.9406
# Iter:184 train_rmse:0.9556 test_loss:33.74 test_rmse:0.03143 test_acc:0.9407
# Iter:185 train_rmse:0.953 test_loss:33.59 test_rmse:0.03135 test_acc:0.9408
# Iter:186 train_rmse:0.9503 test_loss:33.44 test_rmse:0.03128 test_acc:0.941
# Iter:187 train_rmse:0.9477 test_loss:33.29 test_rmse:0.03121 test_acc:0.9411
# Iter:188 train_rmse:0.945 test_loss:33.14 test_rmse:0.03114 test_acc:0.9412
# Iter:189 train_rmse:0.9424 test_loss:32.99 test_rmse:0.03107 test_acc:0.9414
# Iter:190 train_rmse:0.9397 test_loss:32.85 test_rmse:0.031 test_acc:0.9415
# Iter:191 train_rmse:0.9371 test_loss:32.7 test_rmse:0.03093 test_acc:0.9416
# Iter:192 train_rmse:0.9345 test_loss:32.56 test_rmse:0.03086 test_acc:0.9418
# Iter:193 train_rmse:0.9319 test_loss:32.42 test_rmse:0.03079 test_acc:0.9419
# Iter:194 train_rmse:0.9293 test_loss:32.28 test_rmse:0.03073 test_acc:0.942
# Iter:195 train_rmse:0.9266 test_loss:32.14 test_rmse:0.03066 test_acc:0.9421
# Iter:196 train_rmse:0.924 test_loss:32.0 test_rmse:0.03059 test_acc:0.9423
# Iter:197 train_rmse:0.9215 test_loss:31.86 test_rmse:0.03052 test_acc:0.9424
# Iter:198 train_rmse:0.9189 test_loss:31.73 test_rmse:0.03046 test_acc:0.9425
# Iter:199 train_rmse:0.9163 test_loss:31.59 test_rmse:0.03039 test_acc:0.9426
# Iter:200 train_rmse:0.9137 test_loss:31.46 test_rmse:0.03033 test_acc:0.9428
# Iter:201 train_rmse:0.9111 test_loss:31.33 test_rmse:0.03026 test_acc:0.9429
# Iter:202 train_rmse:0.9086 test_loss:31.2 test_rmse:0.0302 test_acc:0.943
# Iter:203 train_rmse:0.906 test_loss:31.07 test_rmse:0.03013 test_acc:0.9431
# Iter:204 train_rmse:0.9035 test_loss:30.94 test_rmse:0.03007 test_acc:0.9433
# Iter:205 train_rmse:0.9009 test_loss:30.81 test_rmse:0.03001 test_acc:0.9434
# Iter:206 train_rmse:0.8984 test_loss:30.68 test_rmse:0.02994 test_acc:0.9435
# Iter:207 train_rmse:0.8959 test_loss:30.56 test_rmse:0.02988 test_acc:0.9436
# Iter:208 train_rmse:0.8934 test_loss:30.43 test_rmse:0.02982 test_acc:0.9437
# Iter:209 train_rmse:0.8909 test_loss:30.31 test_rmse:0.02976 test_acc:0.9438
# Iter:210 train_rmse:0.8884 test_loss:30.19 test_rmse:0.0297 test_acc:0.944
# Iter:211 train_rmse:0.8859 test_loss:30.07 test_rmse:0.02964 test_acc:0.9441
# Iter:212 train_rmse:0.8835 test_loss:29.95 test_rmse:0.02958 test_acc:0.9442
# Iter:213 train_rmse:0.881 test_loss:29.83 test_rmse:0.02952 test_acc:0.9443
# Iter:214 train_rmse:0.8786 test_loss:29.71 test_rmse:0.02946 test_acc:0.9444
# Iter:215 train_rmse:0.8761 test_loss:29.59 test_rmse:0.0294 test_acc:0.9445
# Iter:216 train_rmse:0.8737 test_loss:29.47 test_rmse:0.02934 test_acc:0.9446
# Iter:217 train_rmse:0.8713 test_loss:29.36 test_rmse:0.02928 test_acc:0.9447
# Iter:218 train_rmse:0.8689 test_loss:29.24 test_rmse:0.02922 test_acc:0.9449
# Iter:219 train_rmse:0.8665 test_loss:29.13 test_rmse:0.02916 test_acc:0.945
# Iter:220 train_rmse:0.8642 test_loss:29.02 test_rmse:0.02911 test_acc:0.9451
# Iter:221 train_rmse:0.8618 test_loss:28.9 test_rmse:0.02905 test_acc:0.9452
# Iter:222 train_rmse:0.8595 test_loss:28.79 test_rmse:0.02899 test_acc:0.9453
# Iter:223 train_rmse:0.8571 test_loss:28.68 test_rmse:0.02894 test_acc:0.9454
# Iter:224 train_rmse:0.8548 test_loss:28.58 test_rmse:0.02888 test_acc:0.9455
# Iter:225 train_rmse:0.8525 test_loss:28.47 test_rmse:0.02882 test_acc:0.9456
# Iter:226 train_rmse:0.8502 test_loss:28.36 test_rmse:0.02877 test_acc:0.9457
# Iter:227 train_rmse:0.8479 test_loss:28.26 test_rmse:0.02872 test_acc:0.9458
# Iter:228 train_rmse:0.8456 test_loss:28.16 test_rmse:0.02866 test_acc:0.9459
# Iter:229 train_rmse:0.8434 test_loss:28.05 test_rmse:0.02861 test_acc:0.946
# Iter:230 train_rmse:0.8411 test_loss:27.95 test_rmse:0.02856 test_acc:0.9461
# Iter:231 train_rmse:0.8389 test_loss:27.86 test_rmse:0.02851 test_acc:0.9462
# Iter:232 train_rmse:0.8367 test_loss:27.76 test_rmse:0.02846 test_acc:0.9463
# Iter:233 train_rmse:0.8346 test_loss:27.67 test_rmse:0.02841 test_acc:0.9464
# Iter:234 train_rmse:0.8324 test_loss:27.57 test_rmse:0.02836 test_acc:0.9465
# Iter:235 train_rmse:0.8303 test_loss:27.48 test_rmse:0.02831 test_acc:0.9466
# Iter:236 train_rmse:0.8281 test_loss:27.39 test_rmse:0.02826 test_acc:0.9467
# Iter:237 train_rmse:0.8261 test_loss:27.3 test_rmse:0.02822 test_acc:0.9468
# Iter:238 train_rmse:0.8241 test_loss:27.22 test_rmse:0.02817 test_acc:0.9468
# Iter:239 train_rmse:0.822 test_loss:27.14 test_rmse:0.02813 test_acc:0.9469
# Iter:240 train_rmse:0.82 test_loss:27.05 test_rmse:0.02809 test_acc:0.947
# Iter:241 train_rmse:0.8181 test_loss:26.98 test_rmse:0.02804 test_acc:0.9471
# Iter:242 train_rmse:0.8162 test_loss:26.9 test_rmse:0.028 test_acc:0.9472
# Iter:243 train_rmse:0.8143 test_loss:26.82 test_rmse:0.02796 test_acc:0.9472
# Iter:244 train_rmse:0.8125 test_loss:26.75 test_rmse:0.02792 test_acc:0.9473
# Iter:245 train_rmse:0.8107 test_loss:26.68 test_rmse:0.02789 test_acc:0.9474
# Iter:246 train_rmse:0.809 test_loss:26.61 test_rmse:0.02785 test_acc:0.9474
# Iter:247 train_rmse:0.8074 test_loss:26.54 test_rmse:0.02782 test_acc:0.9475
# Iter:248 train_rmse:0.8059 test_loss:26.48 test_rmse:0.02778 test_acc:0.9476
# Iter:249 train_rmse:0.8044 test_loss:26.42 test_rmse:0.02775 test_acc:0.9476
# 1114.8746044635773 s

# %%
############## visualization ###############
b = int(len(batch_rmse)/totalbatch)
batch_rmse1 = [i for i in batch_rmse]
train_rmse = [(sum(batch_rmse1[i*totalbatch:(i+1)*totalbatch])/totalbatch) for i in range(b)]
batch_loss1 = [i for i in batch_loss]
train_loss = [(sum(batch_loss1[i*totalbatch:(i+1)*totalbatch])/totalbatch) for i in range(b)]

index = test_rmse.index(np.min(test_rmse))
test_result = test_pred[index]
var = pd.DataFrame(test_result)
var.to_csv(path+'/test_result.csv',index = False,header = False)
#plot_result(test_result,test_label1,path)
plot_error(train_rmse,train_loss,test_rmse,test_acc,test_mae,path)

print('min_rmse:%r'%(np.min(test_rmse)),
      'min_mae:%r'%(test_mae[index]),
      'max_acc:%r'%(test_acc[index]),
      'r2:%r'%(test_r2[index]),
      'var:%r'%test_var[index])
# Out:
# min_rmse:1.1404952792908118 min_mae:0.9371520745301194 max_acc:0.9476345415243894 r2:0.976046160035325 var:0.9879753566908264

# %%
all_mse, all_rmse, all_mae, all_r2, all_var = [], [], [], [], []
for i in range(1,118):
    a,b = test_label[:,i], test_output[:,i] 
    mse1 = mean_squared_error(a,b)
    rmse1 = math.sqrt(mean_squared_error(a,b))
    mae1 = mean_absolute_error(a, b)
    #F_norm = la.norm(a-b,'fro')/la.norm(a,'fro')
    r21 = 1-((a-b)**2).sum()/((a-a.mean())**2).sum()
    var1 = 1-(np.var(a-b))/np.var(a)
    all_mse.append(mse1)
    all_rmse.append(rmse1)
    all_mae.append(mae1)
    all_r2.append(r21)
    all_var.append(var1)

### All_rmse
fig1 = plt.figure(figsize=(10,6))
plt.plot(all_rmse, 'ro', label="all_rmse")
plt.plot(all_rmse, 'b-')
plt.legend(loc='best',fontsize=10)
plt.xlabel('BUS Index')
plt.ylabel('RMSE')
plt.savefig('all_rmse.png')
plt.show()

fig5 = plt.figure(figsize=(10,6))
plt.plot(all_mse, 'ro', label="all_mse")
plt.plot(all_mse, 'b-')
plt.legend(loc='best',fontsize=10)
plt.xlabel('BUS Index')
plt.ylabel('MSE')
plt.savefig('all_mse.png')
plt.show()

fig2 = plt.figure(figsize=(10,6))
plt.plot(all_mae, '-o', label="all_mae")
plt.legend(loc='best',fontsize=10)
plt.xlabel('BUS Index')
plt.ylabel('MAE')
plt.savefig('all_mae.png')
plt.show()

fig3 = plt.figure(figsize=(5,3))
plt.plot(all_r2, '-o', label="all_r2")
plt.legend(loc='best',fontsize=10)
plt.xlabel('BUS Index')
plt.ylabel('R2')
plt.savefig('all_r2.png')
plt.show()

fig4 = plt.figure(figsize=(5,3))
plt.plot(all_var, '-o', label="all_var")
plt.legend(loc='best',fontsize=10)
plt.xlabel('BUS Index')
plt.ylabel('VAR')
plt.savefig('all_var.png')
plt.show()
# Out:
# C:\Users\MDJAKI~1\AppData\Local\Temp/ipykernel_16028/1197516776.py:8: RuntimeWarning: divide by zero encountered in double_scalars
#   r21 = 1-((a-b)**2).sum()/((a-a.mean())**2).sum()
# C:\Users\MDJAKI~1\AppData\Local\Temp/ipykernel_16028/1197516776.py:9: RuntimeWarning: divide by zero encountered in double_scalars
#   var1 = 1-(np.var(a-b))/np.var(a)

# %%
print(np.mean(all_rmse), np.std(all_rmse))
print(np.mean(all_mse), np.std(all_mse))
print(np.mean(all_mae), np.std(all_mae))
# Out:
# 0.025832621515645846 0.010166211077740099
# 0.0007706761820477743 0.0006228442314696937
# 0.022789176699092428 0.010080387605698094
